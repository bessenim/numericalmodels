# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv('tesla.csv')
data=data.iloc[::-1]
price = data['Close']
n2 = 35
priceMA2 = price.rolling(center=False,window=n2).mean().values
plt.plot(price.values)
plt.plot(priceMA2)

plt.title('Tesla Motors, 1.1.2014-1.1.2017')
plt.ylabel('Price, $')
plt.xlabel('Days')

# %%
import math

def profit(x):
    securities = 0
    cashInit = 1000000
    cash = cashInit
    n = math.floor(x[0])
    priceAvg = price.rolling(center=False, window=n).mean()
    deals =0
    
    for i in range(n-1, len(price)):
        #buy
        if #condition:

        #sell
        if #condition:
            
    value = -(cash + securities*price.iloc[-1]-cashInit)/cashInit    
    print(value, deals)
    return value

# %%
from scipy.optimize import differential_evolution
bounds = [(1, 50)]
result = differential_evolution(profit, bounds)
result.x, -result.fun*100
